# %% [markdown]
# # **Errores y excepciones**

# %% [markdown]
# Vamos a comprender cómo funcionan las excepciones en Python, cómo leer un traceback, y cómo controlarlas con try/except/else/finally y raise.
#
# Además, conocer a re-lanzar, crear excepciones personalizadas y aplicar prácticas EAFP vs LBYL.

# %% [markdown]
# ## ¿Qué es una excepción?
#
# Una excepción es un mecanismo que utiliza Python para detener la ejecución normal de un programa cuando ocurre un evento inesperado.

# %% [markdown]
# Por ejemplo:

# %% [markdown]
# *   Intentar dividir entre cero,   Acceder a una lista en un índice que no existe.
# *   Acceder a una lista en un índice que no existe.

# %% [markdown]
# Cuando sucede un evento así, Python lanza una excepción (como ZeroDivisionError, IndexError, KeyError, etc) y, si no la manejamos, el programa se detiene.

# %% [markdown]
# ## Diferencia entre error y excepción

# %% [markdown]
# *   **Error (de sintaxis)**. Ocurre antes de ejecutar el programa (olvidar un paréntesis)
# *   **Excepción**: Ocurre durante la ejecución del programa, aunque el código sea sintácticamente correcto.

# %% [markdown]
# ## Jerarquías de excepciones
#
# Python organiza las excepciones en una jerarquía. La mayoría provienen de la clase Exception.

# %% [markdown]
# *   **ValueError**. Conversión inválida.

# %%
# Conversión inválida de texto a número
int("hola")
# ValueError: invalid literal for int() with base 10: 'hola'

# %% [markdown]
# **TypeError**. Operación entre tipos incompatibles.

# %%
"5" + 2
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# **IndexError**. Índice fuera de rango.

# %%
numeros = [10, 20, 30]
print(numeros[5])
# IndexError: list index out of range

# %% [markdown]
# **KeyError**. Clave inexistente en un diccionario.

# %%
persona = {"nombre": "Ana"}
print(persona["edad"])
# KeyError: 'edad'

# %% [markdown]
# **ZeroDivisionError**. División entre cero.

# %%
10 / 0
# ZeroDivisionError: division by zero

# %% [markdown]
# **FileNotFoundError**. Se da al intentar abrir un archivo que no existe.

# %%
open("inexistente.txt")
# FileNotFoundError: [Errno 2] No such file or directory: 'inexistente.txt'

# %% [markdown]
# Entre otros:

# %% [markdown]
# -**PermissionError**
#
# -**AttributeError**
#
# -**ImportError** y **ModuleNotFoundError**
#
# -**IndentationError**
#
# -**RecursionError**

# %% [markdown]
# ## Tracebacks

# %% [markdown]
# El traceback es tu mapa del accidente. Te dice dónde ocurrió, qué función estaba en la pila, qué tipo de excepción y mensaje.
#
# Cuando una excepción no es manejada, Python detiene el programa y muestra el traceback.

# %% [markdown]
# -Dónde ocurrió el error (línea y archivo)
#
# -Qué funciones estaban en ejecución (la “pila de llamadas”)
#
# -Qué tipo de excepción se produjo
#
# -Un mensaje descriptivo asociado a la excepción

# %% [markdown]
# Veamos un ejemplo:

# %%
def dividir(a, b):
    return a / b

def calcular_promedio(total, cantidad):
    return dividir(total, cantidad)

calcular_promedio(10, 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-871502032.py in <cell line: 0>()
#       5     return dividir(total, cantidad)
#       6
# ----> 7 calcular_promedio(10, 0)
#
# /tmp/ipython-input-871502032.py in calcular_promedio(total, cantidad)
#       3
#       4 def calcular_promedio(total, cantidad):
# ----> 5     return dividir(total, cantidad)
#       6
#       7 calcular_promedio(10, 0)
#
# /tmp/ipython-input-871502032.py in dividir(a, b)
#       1 def dividir(a, b):
# ----> 2     return a / b
#       3
#       4 def calcular_promedio(total, cantidad):
#       5     return dividir(total, cantidad)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Lee el traceback de abajo hacia arriba.
#
# El último bloque indica el tipo de excepción (ZeroDivisionError) y el mensaje (‘division by zero’).
#
# Las líneas superiores muestran el camino que siguió el programa hasta llegar al error.

# %% [markdown]
# ## Estructura básica de try/except
#
# La forma más común de manejar excepciones es con un bloque try/except.

# %%
try:
    # Código que podría fallar
    numero = int("hola")
except ValueError:
    # Código que se ejecuta si ocurre ese error
    print("No pude convertir el texto en número.")
# Out:
# No pude convertir el texto en número.

# %% [markdown]
# Si ocurre el error, el programa no se detiene, sino que sigue funcionando.
#
# En lugar de fallar, muestra un mensaje claro y continúa.

# %% [markdown]
# ## Captura de excepciones
# Podemos capturar excepciones específicas.

# %%
try:
    lista = [1, 2, 3]
    print(lista[5])
except IndexError:
    print("Ese índice no existe en la lista.")
# Out:
# Ese índice no existe en la lista.

# %% [markdown]
# O, si es necesario, podemos capturar múltiples excepciones.

# %%
try:
    dato = int("abc")           # Puede dar ValueError
    resultado = lista[10]       # Puede dar IndexError
except ValueError:
    print("La entrada debe ser un número.")
except IndexError:
    print("Ese índice está fuera de rango.")
# Out:
# La entrada debe ser un número.

# %% [markdown]
# ## Bloques con else y finally
#
# -**else**. Se ejecuta si no hubo errores.
#
# -**finally**. Se ejecuta siempre, ocurra o no un error.

# %%
# Ejemplo 1

try:
    num = int("123")
except ValueError:
    print("Hubo un error de conversión.")
else:
    print("Todo salió bien, el número es:", num)
finally:
    print("Este bloque se ejecuta siempre.")


# Ejemplo 2
try:
    f = open("datos.txt")
    contenido = f.read()
except FileNotFoundError:
    print("Archivo no encontrado")
finally:
    f.close()  # Se ejecuta siempre, aunque haya error
# Out:
# Todo salió bien, el número es: 123
# Este bloque se ejecuta siempre.
# Archivo no encontrado
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3613011044.py in <cell line: 0>()
#      18     print("Archivo no encontrado")
#      19 finally:
# ---> 20     f.close()  # Se ejecuta siempre, aunque haya error
#
# NameError: name 'f' is not defined

# %% [markdown]
# ## Lanzar excepciones propias con raise
# A veces es necesario detener el programa intencionalmente si se detecta una condición inválida.

# %%
def dividir(a, b):
    if b == 0:
        raise ValueError("El divisor no puede ser cero.")
    return a / b

# %% [markdown]
# Con raise, se crea un error consciente y explicativo, que ayuda a detectar problemas en fases tempranas.

# %% [markdown]
# ## Re-lanzar y encadenar excepciones
# En ocasiones conviene capturar una excepción para registrarla y luego volver a lanzarla.

# %%
try:
    x = int("abc")
except ValueError:
    print("Error de conversión")
    raise
# Out:
# Error de conversión
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1311891631.py in <cell line: 0>()
#       1 try:
# ----> 2     x = int("abc")
#       3 except ValueError:
#       4     print("Error de conversión")
#       5     raise
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# También podemos encadenar excepciones para dar más contexto:

# %%
try:
    open("config.json")
except FileNotFoundError as e:
    raise RuntimeError("No se pudo iniciar la aplicación: falta config.json") from e
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-759597234.py in <cell line: 0>()
#       1 try:
# ----> 2     open("config.json")
#       3 except FileNotFoundError as e:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config.json'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-759597234.py in <cell line: 0>()
#       2     open("config.json")
#       3 except FileNotFoundError as e:
# ----> 4     raise RuntimeError("No se pudo iniciar la aplicación: falta config.json") from e
#
# RuntimeError: No se pudo iniciar la aplicación: falta config.json

# %% [markdown]
# ## Excepciones personalizadas
# Podemos definir nuestras propias excepciones para representar errores específicos del dominio.

# %%
class ProductoNoEncontrado(Exception):
    def __init__(self, sku):
        super().__init__(f"Producto con SKU '{sku}' no encontrado.")
        self.sku = sku

# %% [markdown]
# Y se aplica de esta forma:

# %%
def obtener_producto(sku, inventario):
    if sku not in inventario:
        raise ProductoNoEncontrado(sku)
    return inventario[sku]

# %% [markdown]
# ## EAFP vs LBYL

# %% [markdown]
# **EAFP** (Easier to Ask Forgiveness than Permission). Intenta y maneja si falla. Estilo recomendado en Python.
#
# **LBYL** (Look Before You Leap). Valida antes de ejecutar.

# %%
# LBYL
if "edad" in persona:
    edad = persona["edad"]
else:
    edad = "desconocida"

# EAFP
try:
    edad = persona["edad"]
except KeyError:
    edad = "desconocida"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-959083348.py in <cell line: 0>()
#       1 # LBYL
# ----> 2 if "edad" in persona:
#       3     edad = persona["edad"]
#       4 else:
#       5     edad = "desconocida"
#
# NameError: name 'persona' is not defined

# %% [markdown]
# En general, se ha preferido en frameworks y herramientas el EAFP, pero ambos enfoques son válidos según el caso.

# %% [markdown]
# -----------

# %% [markdown]
# ## Ejemplos guiados

# %%
# ============================================================
# 1) TRACEBACK
# Escenario: Cálculo de promedio con dato inválido
# (No lo envuelvas en try/except la primera vez para ver el traceback)
# ============================================================

def dividir(a, b):
    return a / b

def promedio(numeros):
    total = sum(numeros)
    cantidad = len(numeros)
    return dividir(total, cantidad)  # Si cantidad=0, verás ZeroDivisionError

# Descomenta para ver un traceback real (y luego vuélvelo a comentar)
# promedio([])  # ZeroDivisionError: division by zero


# ============================================================
# 2) ENTRADA DE USUARIO CON VALIDACIÓN: ValueError + else/finally
#    Escenario: el usuario escribe su edad en un formulario/CLI
# ============================================================

def calcular_edad_futura(entrada):
    # Queremos convertir a int y no romper el programa si fallan
    try:
        edad = int(entrada)  # Puede lanzar ValueError si el usuario escribe "veinte"
    except ValueError:
        print("⚠️ Por favor escribe tu edad como número (ej. 29).")
        return None
    else:
        # Solo se ejecuta si NO hubo excepción
        futura = edad + 5
        print(f"✅ Tu edad en 5 años será: {futura}")
        return futura
    finally:
        # Útil para limpiar recursos o registrar métricas de uso
        # (Aquí solo mostramos una marca de finalización)
        print("ℹ️ Validación de edad finalizada (finally).")

# calcular_edad_futura("veinte")
# calcular_edad_futura("30")


# ============================================================
# 3) MÚLTIPLES EXCEPCIONES Y ORDEN: IndexError, KeyError
#    Escenario: acceder a datos en estructuras (lista/dict)
# ============================================================

def buscar_amigo(lista, idx):
    try:
        return lista[idx]  # IndexError si idx fuera de rango
    except IndexError:
        print("⚠️ Ese índice no existe en la lista.")
        return None

def obtener_campo(usuario, campo):
    try:
        return usuario[campo]  # KeyError si el campo no está
    except KeyError:
        print(f"⚠️ El campo '{campo}' no existe en el perfil.")
        return None

amigos = ["Ana", "Luis", "Sofía"]
usuario = {"nombre": "Ana", "email": "ana@ejemplo.com"}

# buscar_amigo(amigos, 5)
# obtener_campo(usuario, "edad")


# ============================================================
# 4) EAFP vs LBYL: Lectura de clave en diccionario (ambos estilos)
#    Escenario: valor opcional en datos de usuario
# ============================================================

def edad_usuario_LBYL(u):
    # Look Before You Leap: valida antes
    edad = u["edad"] if "edad" in u else "desconocida"
    print("LBYL -> Edad:", edad)
    return edad

def edad_usuario_EAFP(u):
    # Easier to Ask Forgiveness than Permission: intenta y maneja
    try:
        edad = u["edad"]
    except KeyError:
        edad = "desconocida"
    print("EAFP -> Edad:", edad)
    return edad

# edad_usuario_LBYL(usuario)
# edad_usuario_EAFP(usuario)


# ============================================================
# 5) ARCHIVOS: FileNotFoundError, PermissionError y finally
#    Escenario: cargar configuración desde un archivo
# ============================================================

def leer_configuracion(ruta):
    f = None
    try:
        f = open(ruta, "r", encoding="utf-8")  # FileNotFoundError si no existe
        contenido = f.read()
        print("✅ Configuración cargada.")
        return contenido
    except FileNotFoundError:
        print(f"⚠️ No se encontró el archivo de configuración: {ruta}")
        return None
    except PermissionError:
        print(f"⚠️ No tienes permisos para leer: {ruta}")
        return None
    finally:
        if f is not None:
            f.close()  # Cierre garantizado
            print("ℹ️ Archivo cerrado (finally).")

# leer_configuracion("config.json")  # Prueba con ruta inexistente


# ============================================================
# 6) RAISE: Validaciones de negocio con mensajes claros
#    Escenario: retiros en una cuenta
# ============================================================

def retirar(saldo, monto):
    if not isinstance(monto, (int, float)):
        raise TypeError("El monto debe ser numérico.")
    if monto <= 0:
        raise ValueError("El monto a retirar debe ser positivo.")
    if monto > saldo:
        raise ValueError(f"Fondos insuficientes: saldo={saldo}, monto={monto}.")
    return saldo - monto

# print(retirar(100, "50"))   # TypeError
# print(retirar(100, -5))     # ValueError
# print(retirar(100, 150))    # ValueError
# print(retirar(100, 25))     # 75


# ============================================================
# 7) RE-LANZAR Y ENCADENAR: Logging y contexto adicional
#    Escenario: cargar JSON obligatorio al iniciar la app
# ============================================================

import json
import logging
logging.basicConfig(level=logging.INFO)

def cargar_config_obligatoria(ruta):
    try:
        with open(ruta, "r", encoding="utf-8") as f:
            return json.load(f)  # Puede lanzar JSONDecodeError
    except FileNotFoundError as e:
        logging.exception("Falta archivo de configuración.")
        # Encadenar con contexto claro para el usuario/soporte
        raise RuntimeError("No se pudo iniciar: config ausente.") from e
    except json.JSONDecodeError as e:
        logging.exception("Config corrupta o inválida.")
        # Re-lanzar misma excepción preservando el traceback original
        raise

# cargar_config_obligatoria("no_existe.json")


# ============================================================
# 8) ATRIBUTOS E IMPORTS: AttributeError, ImportError/ModuleNotFoundError
#    Escenario: confusiones comunes de principiantes
# ============================================================

def ejemplo_atributos():
    texto = "Hola"
    try:
        # .push no existe en str (confundir con listas)
        texto.push("!")  # AttributeError
    except AttributeError as e:
        print("⚠️ Método inexistente para str:", e)

def ejemplo_imports():
    try:
        import matematicas  # ModuleNotFoundError si no existe
    except ModuleNotFoundError as e:
        print("⚠️ Módulo no encontrado:", e)
    try:
        from math import raiz  # ImportError: 'raiz' no existe en math
    except ImportError as e:
        print("⚠️ Sí existe el módulo, pero no ese nombre:", e)

# ejemplo_atributos()
# ejemplo_imports()


# ============================================================
# 9) EXCEPCIONES PERSONALIZADAS: Errores de dominio (inventario)
#    Escenario: mini-inventario
# ============================================================

class InventarioError(Exception):
    """Error general del inventario."""

class ProductoNoEncontrado(InventarioError):
    def __init__(self, sku):
        super().__init__(f"Producto con SKU '{sku}' no encontrado.")
        self.sku = sku

class StockInsuficiente(InventarioError):
    def __init__(self, sku, solicitado, disponible):
        super().__init__(f"Stock insuficiente para '{sku}': solicitado={solicitado}, disponible={disponible}")
        self.sku = sku
        self.solicitado = solicitado
        self.disponible = disponible

inventario = {
    "SKU-001": {"nombre": "Teclado", "precio": 500.0, "cantidad": 3},
    "SKU-002": {"nombre": "Mouse", "precio": 300.0, "cantidad": 0},
}

def obtener_producto(sku):
    try:
        return inventario[sku]
    except KeyError as e:
        # Convertimos un error genérico en uno de dominio con mensaje amigable
        raise ProductoNoEncontrado(sku) from e

def vender_producto(sku, unidades):
    prod = obtener_producto(sku)
    if unidades <= 0:
        raise ValueError("Las unidades a vender deben ser positivas.")
    if unidades > prod["cantidad"]:
        raise StockInsuficiente(sku, unidades, prod["cantidad"])
    prod["cantidad"] -= unidades
    return prod["cantidad"]

# try:
#     vender_producto("SKU-003", 1)  # ProductoNoEncontrado
# except InventarioError as e:
#     print("⚠️ Inventario:", e)

# try:
#     vender_producto("SKU-002", 2)  # StockInsuficiente
# except InventarioError as e:
#     print("⚠️ Inventario:", e)

# %% [markdown]
# ---

# %% [markdown]
# ## Ejercicio 1
# Implementa a_entero(texto) que:
#
# -Devuelva int(texto) si el string representa un entero válido (p. ej. "42", "-10").
#
# -Si no es convertible, no lance excepción: imprime "Entrada inválida" y devuelve None.

# %%
a_entero("42") => 42
a_entero("cuarenta") => imprime "Entrada inválida" y devuelve None
a_entero("3.14") => imprime "Entrada inválida" y devuelve None (no es entero)

# %%
def a_entero(texto):
    try:
        # Intentar convertir a entero
        return int(texto)
    except ValueError:
        # Si no se puede convertir, mostrar mensaje y devolver None
        print("Entrada inválida")
        return None

# %%
print(a_entero("42"))       # 42
print(a_entero("cuarenta")) # imprime "Entrada inválida" -> None
print(a_entero("3.14"))     # imprime "Entrada inválida" -> None
print(a_entero("-10"))      # -10
# Out:
# 42
# Entrada inválida
# None
# Entrada inválida
# None
# -10

# %% [markdown]
# ## Ejercicio 2
#
# Implementa item_en(lista, i) que:
#
# -Devuelva el elemento en índice i.
#
# -Si i está fuera de rango (positivo o negativo), imprima "Índice fuera de rango" y devuelva None.

# %%
item_en([1,2,3], 1) => 2
item_en([1,2,3], 5) => imprime y devuelve None
item_en([1,2,3], -4) => imprime y devuelve None (−1, −2, −3 sí funcionan; −4 no)

# %%
def item_en(lista, i):
    try:
        return lista[i]
    except IndexError:
        print("Índice fuera de rango")
        return None

# %%
print(item_en([1,2,3], 1))   # 2
print(item_en([1,2,3], 5))   # imprime "Índice fuera de rango" → None
print(item_en([1,2,3], -4))  # imprime "Índice fuera de rango" → None
# Out:
# 2
# Índice fuera de rango
# None
# Índice fuera de rango
# None

# %% [markdown]
# ## Ejercicio 3
#
# Implementa leer_edad(usuario) que:
#
# -Intente leer usuario["edad"] y convertirla a int.
#
# -Si falta la clave, imprime "Falta edad", devuelve None.
#
# -Si la conversión falla, imprime "Edad inválida", devuelve None.

# %%
leer_edad({"edad":"30"}) → 30
leer_edad({}) → "Falta edad", None
leer_edad({"edad":"treinta"}) → "Edad inválida", None

# %%
def leer_edad(usuario):
    # 1. Verificar si la clave existe
    if "edad" not in usuario:
        print("Falta edad")
        return None

    valor = usuario["edad"]

    # 2. Intentar convertir a entero
    try:
        return int(valor)
    except ValueError:
        print("Edad inválida")
        return None

# %%
print(leer_edad({"edad": "30"}))        # 30
print(leer_edad({}))                    # imprime "Falta edad" → None
print(leer_edad({"edad": "treinta"}))   # imprime "Edad inválida" → None
# Out:
# 30
# Falta edad
# None
# Edad inválida
# None

# %% [markdown]
# ## Ejercicio 4
#
# Implementa suma_segura(a, b) que:
#
# -Convierta a y b a float y retorne su suma.
#
# -Imprima "Dato inválido" si alguna conversión falla.
#
# -Si todo sale bien, imprima "OK" en else.
#
# -Imprima siempre "Hecho" en finally.

# %%
suma_segura("2", "3.5") → imprime OK, Hecho; retorna 5.5
suma_segura("2", "x") → imprime Dato inválido, Hecho; retorna None

# %%
def suma_segura(a, b):
    try:
        x = float(a)
        y = float(b)
        resultado = x + y
    except ValueError:
        print("Dato inválido")
        return None
    else:
        print("OK")
        return resultado
    finally:
        print("Hecho")

# %%
suma_segura("2", "3.5")
# Imprime:
# OK
# Hecho
# Devuelve: 5.5

suma_segura("2", "x")
# Imprime:
# Dato inválido
# Hecho
# Devuelve: None
# Out:
# OK
# Hecho
# Dato inválido
# Hecho

# %% [markdown]
# ## Ejercicio 5
#
# Implementa retirar(saldo, monto) que:
#
# -Lance TypeError si monto no es numérico.
#
# -Lance ValueError si monto <= 0 o monto > saldo.
#
# -Devuelva el nuevo saldo si todo es válido.

# %%
retirar(100, 40) → 60
retirar(100, "20") → TypeError
retirar(100, -5) → ValueError
retirar(100, 150) → ValueError

# %%
def retirar(saldo, monto):
    # 1) Validar que monto sea numérico
    if not isinstance(monto, (int, float)):
        raise TypeError("El monto debe ser numérico")

    # 2) Validar reglas de negocio
    if monto <= 0:
        raise ValueError("El monto debe ser mayor que cero")
    if monto > saldo:
        raise ValueError("Fondos insuficientes")

    # 3) Todo OK → devolver nuevo saldo
    return saldo - monto

# %%
print(retirar(100, 40))     # 60

retirar(100, "20")          # TypeError

retirar(100, -5)            # ValueError

retirar(100, 150)           # ValueError
# Out:
# 60
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3461546440.py in <cell line: 0>()
#       1 print(retirar(100, 40))     # 60
#       2
# ----> 3 retirar(100, "20")          # TypeError
#       4
#       5 retirar(100, -5)            # ValueError
#
# /tmp/ipython-input-118642447.py in retirar(saldo, monto)
#       2     # 1) Validar tipo
#       3     if type(monto) not in (int, float):
# ----> 4         raise TypeError("El monto debe ser numérico")
#       5
#       6     # 2) Validar monto positivo
#
# TypeError: El monto debe ser numérico

# %% [markdown]
# ## Ejercicio 6
#
# Implementa dos funciones para obtener "email" de usuario:
#
# -email_LBYL(usuario) usando "email" in usuario.
#
# -email_EAFP(usuario) usando try/except KeyError. Ambas devuelven el email o "desconocido".

# %%
email_LBYL({"email":"a@b.com"}) → "a@b.com"
email_LBYL({"nombre":"Ana"}) → "desconocido"
email_EAFP({"email":"a@b.com"}) → "a@b.com"
email_EAFP({}) → "desconocido"

# %%
def email_LBYL(usuario):
    if "email" in usuario:
        return usuario["email"]
    else:
        return "desconocido"

# %%
def email_EAFP(usuario):
    try:
        return usuario["email"]
    except KeyError:
        return "desconocido"

# %%
print(email_LBYL({"email": "a@b.com"}))   # "a@b.com"
print(email_LBYL({"nombre": "Ana"}))      # "desconocido"

print(email_EAFP({"email": "a@b.com"}))   # "a@b.com"
print(email_EAFP({}))                     # "desconocido"
# Out:
# a@b.com
# desconocido
# a@b.com
# desconocido

# %% [markdown]
# ## Ejercicio 7
#
# Implementa leer_texto(ruta) que:
#
# -Devuelva el contenido del archivo si existe.
#
# -Si no existe, imprima "No encontrado" y devuelva "".
#
# -Si no hay permisos, imprima "Sin permiso" y devuelva "".
#
# -Siempre cierre el archivo (si se abrió).

# %%
leer_texto("noexiste.txt") → imprime "No encontrado", devuelve ""
leer_texto("datos.txt") → devuelve "Hola mundo"
leer_texto("/etc/shadow") → imprime "Sin permiso", devuelve ""

# %%
def leer_texto(ruta):
    archivo = None
    try:
        archivo = open(ruta, "r")
        contenido = archivo.read()
        return contenido

    except FileNotFoundError:
        print("No encontrado")
        return ""

    except PermissionError:
        print("Sin permiso")
        return ""

    finally:
        if archivo is not None:
            archivo.close()

# %%
leer_texto("noexiste.txt")
# Imprime: No encontrado
# Devuelve: ""

leer_texto("datos.txt")
# Devuelve: "Hola mundo"

leer_texto("/etc/shadow")
# Imprime: Sin permiso
# Devuelve: ""
# Out:
# No encontrado
# No encontrado
# 'root:*:19901:0:99999:7:::\ndaemon:*:19901:0:99999:7:::\nbin:*:19901:0:99999:7:::\nsys:*:19901:0:99999:7:::\nsync:*:19901:0:99999:7:::\ngames:*:19901:0:99999:7:::\nman:*:19901:0:99999:7:::\nlp:*:19901:0:99999:7:::\nmail:*:19901:0:99999:7:::\nnews:*:19901:0:99999:7:::\nuucp:*:19901:0:99999:7:::\nproxy:*:19901:0:99999:7:::\nwww-data:*:19901:0:99999:7:::\nbackup:*:19901:0:99999:7:::\nlist:*:19901:0:99999:7:::\nirc:*:19901:0:99999:7:::\ngnats:*:19901:0:99999:7:::\nnobody:*:19901:0:99999:7:::\n_apt:*:19901:0:99999:7:::\nsystemd-network:*:20412:0:99999:7:::\nsystemd-resolve:*:20412:0:99999:7:::\nmessagebus:*:20412:0:99999:7:::\n'

# %%
print("1) Archivo inexistente:")
print(leer_texto("noexiste.txt"))

print("\n2) Archivo accesible:")
print(leer_texto("/etc/passwd"))

print("\n3) Archivo sin permiso:")
print(leer_texto("/etc/shadow"))
# Out:
# 1) Archivo inexistente:
# No encontrado
#
#
# 2) Archivo accesible:
# root:x:0:0:root:/root:/bin/bash
# daemon:x:1:1:daemon:/usr/sbin:/usr/sbin/nologin
# bin:x:2:2:bin:/bin:/usr/sbin/nologin
# sys:x:3:3:sys:/dev:/usr/sbin/nologin
# sync:x:4:65534:sync:/bin:/bin/sync
# games:x:5:60:games:/usr/games:/usr/sbin/nologin
# man:x:6:12:man:/var/cache/man:/usr/sbin/nologin
# lp:x:7:7:lp:/var/spool/lpd:/usr/sbin/nologin
# mail:x:8:8:mail:/var/mail:/usr/sbin/nologin
# news:x:9:9:news:/var/spool/news:/usr/sbin/nologin
# uucp:x:10:10:uucp:/var/spool/uucp:/usr/sbin/nologin
# proxy:x:13:13:proxy:/bin:/usr/sbin/nologin
# www-data:x:33:33:www-data:/var/www:/usr/sbin/nologin
# backup:x:34:34:backup:/var/backups:/usr/sbin/nologin
# list:x:38:38:Mailing List Manager:/var/list:/usr/sbin/nologin
# irc:x:39:39:ircd:/run/ircd:/usr/sbin/nologin
# gnats:x:41:41:Gnats Bug-Reporting System (admin):/var/lib/gnats:/usr/sbin/nologin
# nobody:x:65534:65534:nobody:/nonexistent:/usr/sbin/nologin
# _apt:x:100:65534::/nonexistent:/usr/sbin/nologin
# systemd-network:x:101:102:systemd Network Management,,,:/run/systemd:/usr/sbin/nologin
# systemd-resolve:x:102:103:systemd Resolver,,,:/run/systemd:/usr/sbin/nologin
# messagebus:x:103:104::/nonexistent:/usr/sbin/nologin
#
#
# 3) Archivo sin permiso:
# root:*:19901:0:99999:7:::
# daemon:*:19901:0:99999:7:::
# bin:*:19901:0:99999:7:::
# sys:*:19901:0:99999:7:::
# sync:*:19901:0:99999:7:::
# games:*:19901:0:99999:7:::
# man:*:19901:0:99999:7:::
# lp:*:19901:0:99999:7:::
# mail:*:19901:0:99999:7:::
# news:*:19901:0:99999:7:::
# uucp:*:19901:0:99999:7:::
# proxy:*:19901:0:99999:7:::
# www-data:*:19901:0:99999:7:::
# backup:*:19901:0:99999:7:::
# list:*:19901:0:99999:7:::
# irc:*:19901:0:99999:7:::
# gnats:*:19901:0:99999:7:::
# nobody:*:19901:0:99999:7:::
# _apt:*:19901:0:99999:7:::
# systemd-network:*:20412:0:99999:7:::
# systemd-resolve:*:20412:0:99999:7:::
# messagebus:*:20412:0:99999:7:::

# %% [markdown]
# ## Ejercicio 8
# Implementa cargar_config(ruta) que:
#
# -Abra y parseé JSON.
#
# -Si el archivo no existe, lance RuntimeError("Config ausente") encadenado con la causa real.
#
# -Si el JSON es inválido, registre el error y re-lance JSONDecodeError.

# %%
cargar_config("noexiste.json") → RuntimeError("Config ausente") (con causa FileNotFoundError).
cargar_config("valido.json") → {"debug": True}.
cargar_config("corrupto.json") → JSONDecodeError re-lanzado.

# %% [markdown]
# ✅ CÓDIGO FINAL DEL EJERCICIO (cargar_config)

# %%
import json

def cargar_config(ruta):
    try:
        with open(ruta, "r") as f:
            return json.load(f)

    except FileNotFoundError as e:
        raise RuntimeError("Config ausente") from e

    except json.JSONDecodeError as e:
        print("Error al parsear JSON:", e)
        raise

# %% [markdown]
# ✅ CREAR TODOS LOS ARCHIVOS NECESARIOS PARA PROBAR

# %%
with open("valido.json", "w") as f:
    f.write('{"debug": true}')

# %%
with open("corrupto.json", "w") as f:
    f.write('{"debug": truue}')

# %% [markdown]
# ✅ PRUEBAS EXACTAS DEL EJERCICIO

# %%
print("1) Archivo inexistente:")
try:
    cargar_config("noexiste.json")
except Exception as e:
    print(type(e).__name__, "-", e)
# Out:
# 1) Archivo inexistente:
# RuntimeError - Config ausente

# %%
{'debug': True}
# Out:
# {'debug': True}

# %%
print("3) Archivo corrupto:")
try:
    cargar_config("corrupto.json")
except Exception as e:
    print(type(e).__name__, "-", e)
# Out:
# 3) Archivo corrupto:
# Error al parsear JSON: Expecting value: line 1 column 11 (char 10)
# JSONDecodeError - Expecting value: line 1 column 11 (char 10)

# %%
import json
import logging
logging.basicConfig(level=logging.INFO)

def cargar_config(ruta):
    """Carga JSON obligatorio con contexto claro al fallar."""
    try:
        with open(ruta, "r", encoding="utf-8") as f:
            return json.load(f)
    except FileNotFoundError as e:
        # Agregamos un mensaje de negocio y conservamos la causa real
        raise RuntimeError("Config ausente") from e
    except json.JSONDecodeError:
        logging.exception("Config inválida")
        raise  # re-lanzamos la misma excepción para no esconderla

# %% [markdown]
# ## Ejercicio 9
#
# Define:
#
# -InventarioError(Exception)
#
# -ProductoNoEncontrado(InventarioError)
#
# -StockInsuficiente(InventarioError) Implementa vender(inventario, sku, unidades) que:
#
# -Lance ProductoNoEncontrado si no existe el SKU.
#
# -Lance ValueError si unidades <= 0.
#
# -Lance StockInsuficiente si no hay stock suficiente.
#
# -Devuelva la cantidad restante si todo es válido.

# %%
Inventario: {"A1":{"cantidad":3}, "B2":{"cantidad":0}}
vender(inv, "A1", 2) → 1 (restan 1).
vender(inv, "B2", 1) → StockInsuficiente con mensaje "solicitado=1, disponible=0".
vender(inv, "C3", 1) → ProductoNoEncontrado con mensaje "Producto 'C3' no encontrado.".
vender(inv, "A1", -5) → ValueError("Las unidades deben ser positivas.").

# %%
class InventarioError(Exception):
    """Error base para inventario."""
    pass

class ProductoNoEncontrado(InventarioError):
    """Se lanza cuando un SKU no existe."""
    pass

class StockInsuficiente(InventarioError):
    """Se lanza cuando no hay stock suficiente."""
    pass

# %%
def vender(inventario, sku, unidades):
    # 1) Validar que el SKU exista
    if sku not in inventario:
        raise ProductoNoEncontrado(f"Producto '{sku}' no encontrado.")

    # 2) Validar que unidades sea positivo
    if unidades <= 0:
        raise ValueError("Las unidades deben ser positivas.")

    disponible = inventario[sku]["cantidad"]

    # 3) Validar stock suficiente
    if unidades > disponible:
        raise StockInsuficiente(f"solicitado={unidades}, disponible={disponible}")

    # 4) Restar stock y devolver lo que queda
    inventario[sku]["cantidad"] -= unidades
    return inventario[sku]["cantidad"]

# %%
inv = {"A1": {"cantidad": 3}, "B2": {"cantidad": 0}}

# %%
print(vender(inv, "A1", 2))
# Out:
# 1

# %%
vender(inv, "B2", 1)
# Out:
# ---------------------------------------------------------------------------
# StockInsuficiente                         Traceback (most recent call last)
# /tmp/ipython-input-1541421177.py in <cell line: 0>()
# ----> 1 vender(inv, "B2", 1)
#
# /tmp/ipython-input-66877028.py in vender(inventario, sku, unidades)
#      12     # 3) Validar stock suficiente
#      13     if unidades > disponible:
# ---> 14         raise StockInsuficiente(f"solicitado={unidades}, disponible={disponible}")
#      15
#      16     # 4) Restar stock y devolver lo que queda
#
# StockInsuficiente: solicitado=1, disponible=0

# %%
vender(inv, "C3", 1)
# Out:
# ---------------------------------------------------------------------------
# ProductoNoEncontrado                      Traceback (most recent call last)
# /tmp/ipython-input-149567869.py in <cell line: 0>()
# ----> 1 vender(inv, "C3", 1)
#
# /tmp/ipython-input-66877028.py in vender(inventario, sku, unidades)
#       2     # 1) Validar que el SKU exista
#       3     if sku not in inventario:
# ----> 4         raise ProductoNoEncontrado(f"Producto '{sku}' no encontrado.")
#       5
#       6     # 2) Validar que unidades sea positivo
#
# ProductoNoEncontrado: Producto 'C3' no encontrado.

# %%
vender(inv, "A1", -5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4089482109.py in <cell line: 0>()
# ----> 1 vender(inv, "A1", -5)
#
# /tmp/ipython-input-66877028.py in vender(inventario, sku, unidades)
#       6     # 2) Validar que unidades sea positivo
#       7     if unidades <= 0:
# ----> 8         raise ValueError("Las unidades deben ser positivas.")
#       9
#      10     disponible = inventario[sku]["cantidad"]
#
# ValueError: Las unidades deben ser positivas.

# %% [markdown]
# ---

# %% [markdown]
# # **Archivos .txt**

# %% [markdown]
# Vamos ahora a abrir, leer y escribir archivos de texto en Python de manera segura, entendiendo los distintos modos (r, w, a) y usando with como context manager para asegurar el cierre automático del archivo.
#
#
# ### ¿Qué es un archivo de texto plano?
#
# Un archivo de texto es un contenedor de datos en forma de caracteres.
#
# -Cada carácter (letra, número, símbolo) se almacena como un byte o varios bytes (dependiendo de la codificación).
#
# -Los archivos .txt no contienen “formato” (como negritas o imágenes), solo texto legible.
#
# -Ejemplos generales. listas de pendientes, registros de logs, configuraciones simples.
#
# -Tipos. .txt, .csv, .log.
#
# -Se puede abrir con cualquier editor (Notepad, VS Code, etc.).
#
# En Python, trabajamos con archivos a través de funciones que leen/escriben cadenas de texto.
#
# Esto los convierte en la forma más universal de guardar información: cualquier programa puede abrirlos.

# %% [markdown]
# ## La función open()
# La función básica para interactuar con archivos es:

# %%
open(ruta, modo, encoding="utf-8")

# %% [markdown]
# open(ruta, modo) abre un archivo y devuelve un objeto de tipo file.

# %% [markdown]
# **Parámetros principales**
#
# -**ruta**. El nombre o ruta del archivo ("datos.txt" o "/home/user/datos.txt").
#
# -**modo**. Indica qué queremos hacer con el archivo.
#
# -**encoding**. La codificación de texto. El estándar moderno es "utf-8".
#
# Cuando ejecutamos open(), Python pide al sistema operativo acceso al archivo:
#
# -Si existe y tenemos permiso, devuelve un objeto archivo.
#
# -Si no existe o no tenemos permisos, se lanza una excepción (FileNotFoundError, PermissionError).

# %% [markdown]
# ### Modos de apertura
# Python define distintos modos, dependiendo de lo que queremos hacer.
#
# "r". Lectura (default). Error si no existe.
#
# "w". Escritura (crea nuevo archivo o sobrescribe si ya existe).
#
# "a". append/agregar (escribe al final, sin borrar lo anterior).
#
# "r+". Lectura y escritura.

# %%
f = open("notas.txt", "r")   # abre en modo lectura
contenido = f.read()
print(contenido)
f.close()   # importante: cerrar después de usar

# %% [markdown]
# ## Leer archivos
# Cuando abrimos un archivo en modo "r", tenemos varias formas de leer su contenido.
#
# -Leer todo el contenido (read)
#
# Devuelve todo el contenido como un string. Es útil para archivos pequeños.

# %%
f = open("notas.txt", "r", encoding="utf-8")
texto = f.read()
f.close()
print(texto)

# %% [markdown]
# -Leer línea por línea (readline)
#
# Procesa una línea a la vez. Útil para archivos grandes.

# %%
f = open("notas.txt", "r", encoding="utf-8")
linea = f.readline()
while linea:
    print("→", linea.strip())
    linea = f.readline()
f.close()

# %% [markdown]
# Guardar todas las líneas en una lista (readlines)

# %%
f = open("notas.txt", "r", encoding="utf-8")
lineas = f.readlines()
f.close()
print(lineas)   # ['Primera línea\n', 'Segunda línea\n']

# %% [markdown]
# -Iterar directamente sobre el archivo
#
# Este es más eficiente para archivos grandes.

# %%
f = open("notas.txt", "r", encoding="utf-8")
for linea in f:
    print("→", linea.strip())
f.close()

# %% [markdown]
# ## Escribir archivos
# Sobrescribir (w)

# %%
f = open("saludo.txt", "w", encoding="utf-8")
f.write("Hola!\n")
f.write("Segunda línea\n")
f.close()

# %% [markdown]
# -Agregar al final (a)

# %%
f = open("saludo.txt", "a", encoding="utf-8")
f.write("Nueva línea agregada\n")
f.close()

# %% [markdown]
# ## Usar with (Context Manager)
#
# Hasta ahora hemos usado open() y close() manualmente.
#
# Pero, si ocurre un error antes de close(), el archivo puede quedar abierto.
#
# -with garantiza que el archivo se cierre automáticamente, incluso si ocurre un error.
#
# -Esto evita fugas de recursos y es la forma recomendada en Python.

# %%
with open("notas.txt", "r", encoding="utf-8") as f:
    contenido = f.read()
# aquí el archivo YA está cerrado automáticamente

# %% [markdown]
# El bloque with funciona como un context manager:
#
# -Garantiza que el archivo se cierre, pase lo que pase.
#
# -Hace el código más corto y legible.

# %% [markdown]
# ## Ejemplo integrador
# Veamos una app de notas simple:

# %%
# Guardar notas (sobrescribir)
with open("notas.txt", "w", encoding="utf-8") as f:
    f.write("Comprar pan\n")
    f.write("Estudiar Python\n")

# Agregar nota
with open("notas.txt", "a", encoding="utf-8") as f:
    f.write("Hacer ejercicio\n")

# Leer notas
with open("notas.txt", "r", encoding="utf-8") as f:
    for i, linea in enumerate(f, start=1):
        print(f"{i}. {linea.strip()}")

# 1. Comprar pan
# 2. Estudiar Python
# 3. Hacer ejercicio
# Out:
# 1. Comprar pan
# 2. Estudiar Python
# 3. Hacer ejercicio

# %% [markdown]
# ---

# %% [markdown]
# ## Ejercicio 1
# Crea un archivo llamado hola.txt que contenga el texto "Hola Python".

# %% [markdown]
# ✅ Crear hola.txt con el texto "Hola Python"

# %%
with open("hola.txt", "w") as f:
    f.write("Hola Python")

# %% [markdown]
# ✔ ¿Qué hace esto?
#
# "w" → modo escritura (si no existe, lo crea; si existe, lo sobrescribe).
#
# f.write("Hola Python") → escribe el contenido dentro del archivo.

# %% [markdown]
# 🔍 Verificar que se creó correctamente

# %%
with open("hola.txt", "r") as f:
    print(f.read())
# Out:
# Hola Python

# %% [markdown]
# ## Ejercicio 2
# Escribe tres frases distintas en un archivo frases.txt. Cada frase debe ir en una nueva línea.

# %% [markdown]
# ✅ Crear frases.txt con tres frases (una por línea)

# %%
with open("frases.txt", "w") as f:
    f.write("Primera frase\n")
    f.write("Segunda frase\n")
    f.write("Tercera frase\n")

# %% [markdown]
# 🔍 Verificar que se guardaron bien

# %%
with open("frases.txt", "r") as f:
    print(f.read())
# Out:
# Primera frase
# Segunda frase
# Tercera frase

# %% [markdown]
# ## Ejercicio 3
# Lee y muestra en pantalla todo el contenido de frases.txt.

# %% [markdown]
# ✅ Leer y mostrar el contenido de frases.txt

# %%
with open("frases.txt", "r") as f:
    contenido = f.read()
    print(contenido)
# Out:
# Primera frase
# Segunda frase
# Tercera frase

# %% [markdown]
# ## Ejercicio 4
# Abre frases.txt y muestra cada línea con un número al inicio.

# %% [markdown]
# ✅ Mostrar cada línea con un número al inicio

# %%
with open("frases.txt", "r") as f:
    for i, linea in enumerate(f, start=1):
        print(f"{i}. {linea.strip()}")
# Out:
# 1. Primera frase
# 2. Segunda frase
# 3. Tercera frase

# %% [markdown]
# ## Ejercicio 5
# Tienes la lista:
#
# tareas = ["Comprar leche", "Estudiar Python", "Hacer ejercicio"]
#
# Guárdala en un archivo tareas.txt, cada tarea en una línea

# %% [markdown]
# ✅ Guardar la lista en tareas.txt

# %%
tareas = ["Comprar leche", "Estudiar Python", "Hacer ejercicio"]

with open("tareas.txt", "w") as f:
    for tarea in tareas:
        f.write(tarea + "\n")

# %% [markdown]
# ✅ Cómo ver si el archivo existe

# %%
import os

os.listdir("/content")
# Out:
# ['.config',
#  'tareas.txt',
#  'frases.txt',
#  'notas.txt',
#  'hola.txt',
#  'corrupto.json',
#  'valido.json',
#  'sample_data']

# %% [markdown]
# ✅ Cómo abrir y mostrar el archivo para confirmar

# %%
with open("tareas.txt", "r") as f:
    print(f.read())
# Out:
# Comprar leche
# Estudiar Python
# Hacer ejercicio

# %% [markdown]
# ✅ Cómo descargar el archivo a tu computadora

# %%
from google.colab import files
files.download("tareas.txt")

# %% [markdown]
# ## Ejercicio 6
# Lee el archivo tareas.txt y guarda cada línea en una lista de Python (sin saltos de línea).

# %% [markdown]
# ✅ Leer tareas.txt y guardar cada línea en una lista

# %%
lista_tareas = []

with open("tareas.txt", "r") as f:
    for linea in f:
        lista_tareas.append(linea.strip())

print(lista_tareas)
# Out:
# ['Comprar leche', 'Estudiar Python', 'Hacer ejercicio']

# %% [markdown]
# ## Ejercicio 7
# Agrega al archivo tareas.txt dos nuevas tareas: "Leer un libro" y "Meditar".

# %% [markdown]
# ✅ Agregar dos nuevas tareas a tareas.txt

# %%
with open("tareas.txt", "a") as f:
    f.write("Leer un libro\n")
    f.write("Meditar\n")

# %% [markdown]
# ✔ ¿Qué hace el código?
#
# "a" → append, agrega al final del archivo sin borrar nada.
#
# Cada write() incluye \n para que quede una tarea por línea.

# %% [markdown]
# ✅ Ver el contenido del archivo tareas.txt

# %%
with open("tareas.txt", "r") as f:
    print(f.read())
# Out:
# Comprar leche
# Estudiar Python
# Hacer ejercicio
# Leer un libro
# Meditar

# %%
with open("tareas.txt", "r") as f:
    for i, linea in enumerate(f, start=1):
        print(f"{i}. {linea.strip()}")
# Out:
# 1. Comprar leche
# 2. Estudiar Python
# 3. Hacer ejercicio
# 4. Leer un libro
# 5. Meditar

# %% [markdown]
# ## Ejercicio 8
# Cuenta cuántas líneas tiene el archivo tareas.txt e imprime el total.

# %% [markdown]
# ✅ Contar líneas de tareas.txt e imprimir el total

# %%
contador = 0

with open("tareas.txt", "r") as f:
    for _ in f:
        contador += 1

print("Total de líneas:", contador)
# Out:
# Total de líneas: 5

# %% [markdown]
# ## Ejercicio 9
# Lee el archivo tareas.txt y guarda su contenido en un nuevo archivo tareas_backup.txt.

# %% [markdown]
# ✅ Copiar el contenido de tareas.txt a tareas_backup.txt

# %%
with open("tareas.txt", "r") as original, open("tareas_backup.txt", "w") as copia:
    for linea in original:
        copia.write(linea)

# %% [markdown]
# ✔ ¿Qué hace este código?
#
# Abre tareas.txt en modo lectura ("r").
#
# Abre tareas_backup.txt en modo escritura ("w").
#
# Copia cada línea tal cual al nuevo archivo.

# %% [markdown]
# 🔍 Verificar que se creó el backup

# %%
with open("tareas_backup.txt", "r") as f:
    print(f.read())
# Out:
# Comprar leche
# Estudiar Python
# Hacer ejercicio
# Leer un libro
# Meditar

# %% [markdown]
# ## Ejercicio 10
# Crea un programa que:
#
# -Guarde en notas.txt tres notas ingresadas por el usuario.
#
# -Después, lea y muestre todas las notas numeradas.

# %% [markdown]
# ✅ Ejercicio 10 — Programa completo
#
# Este código:
#
# Pide 3 notas al usuario.
#
# Las guarda en notas.txt (una por línea).
#
# Luego lee el archivo y muestra las notas numeradas.

# %%
# 1) Guardar tres notas ingresadas por el usuario
with open("notas.txt", "w") as f:
    for i in range(1, 4):
        nota = input(f"Ingrese la nota {i}: ")
        f.write(nota + "\n")

# 2) Leer y mostrar las notas numeradas
print("\nNotas guardadas:")
with open("notas.txt", "r") as f:
    for i, linea in enumerate(f, start=1):
        print(f"{i}. {linea.strip()}")
# Out:
# Ingrese la nota 1: 7
# Ingrese la nota 2: 9
# Ingrese la nota 3: 5
#
# Notas guardadas:
# 1. 7
# 2. 9
# 3. 5

# %% [markdown]
# 🟢 ¿Qué hace el programa?
#
# ✔ Parte 1 — Guardado
#
# range(1, 4) → pide nota 1, nota 2, nota 3
#
# f.write(nota + "\n") → cada nota queda en una línea distinta
#
# ✔ Parte 2 — Lectura numerada
#
# enumerate(..., start=1) → numera desde 1
#
# strip() → elimina el salto de línea

# %%
with open("notas.txt", "w") as f:
    notas = [input(f"Ingrese la nota {i}: ") for i in range(1, 4)]
    f.write("\n".join(notas))

print("\nNotas guardadas:")
with open("notas.txt", "r") as f:
    for i, linea in enumerate(f, start=1):
        print(f"{i}. {linea.strip()}")
# Out:
# Ingrese la nota 1: 8
# Ingrese la nota 2: 7
# Ingrese la nota 3: 10
#
# Notas guardadas:
# 1. 8
# 2. 7
# 3. 10

# %% [markdown]
# ---

# %% [markdown]
# # **Pathlib y rutas**

# %% [markdown]
# Ahora vamos a comprender **rutas absolutas y relativas**, crear/verificar/manipular rutas de forma **segura y multiplataforma** con pathlib, y aplicarlo en Colab.

# %% [markdown]
# ## Contexto en Google Colab

# %% [markdown]
# -El directorio actual suele ser /content.
#
# -El almacenamiento local de Colab (en /content) es temporal: se pierde al reiniciar el runtime.

# %%
# (Puedes ejecutar esto para verificar tu punto de partida)
from pathlib import Path

print("Directorio actual (CWD):", Path.cwd())   # esperado: /content
print("Home del usuario:", Path.home())         # esperado: /root en Colab
# Out:
# Directorio actual (CWD): /content
# Home del usuario: /root

# %% [markdown]
# Por otro lado, si quieres persistencia, tocaría usar Google Drive y trabajar dentro de "/content/drive/MyDrive".

# %% [markdown]
# ## ¿Qué es pathlib?

# %% [markdown]
# pathlib te da un objeto Path que representa rutas (carpetas/archivos) y ofrece métodos claros para operarlas.
#
# Beneficios:
#
# -Multiplataforma: maneja separadores (/ vs \) automáticamente.
#
# -API coherente y legible: p.exists(), p.is_dir(), p.name, p.suffix, etc.
#
# -Menos errores por concatenar strings manualmente.

# %%
from pathlib import Path

base = Path("data_colab")     # ruta RELATIVA a /content
archivo = base / "raw" / "ventas_enero.txt"  # operador "/" compone rutas
print("Ruta compuesta:", archivo)            # data_colab/raw/ventas_enero.txt
# Out:
# Ruta compuesta: data_colab/raw/ventas_enero.txt

# %% [markdown]
# Piensa en Path como "un objeto ruta" que sabe unirse, inspeccionarse y operar en disco.

# %% [markdown]
# ## Rutas absolutas vs relativas
#
# -Relativa: se interpreta respecto al **directorio actual** (CWD).
#
# -Absoluta: comienza en la **raíz** (en Colab "/").

# %%
from pathlib import Path

print("CWD:", Path.cwd())       # p.ej. /content
relativa = Path("data_colab/raw/ventas.txt")
absoluta = relativa.resolve()   # convierte a absoluta (no falla si no existe)
print("Relativa:", relativa)
print("Absoluta:", absoluta)
# Out:
# CWD: /content
# Relativa: data_colab/raw/ventas.txt
# Absoluta: /content/data_colab/raw/ventas.txt

# %% [markdown]
# En Colab, todo lo que crees en "data_colab" vivirá en /content/data_colab y se borrará al resetear el runtime (a menos que uses Drive).

# %% [markdown]
# ## Partes útiles de una ruta
# pathlib permite inspeccionar cómodamente:

# %%
p = Path("data_colab/raw/ventas_enero.csv")
print("name   →", p.name)    # ventas_enero.csv
print("stem   →", p.stem)    # ventas_enero
print("suffix →", p.suffix)  # .csv
print("parent →", p.parent)  # data_colab/raw
print("parts  →", p.parts)   # ('data_colab', 'raw', 'ventas_enero.csv')

print("Cambiar extensión:", p.with_suffix(".txt"))
print("Cambiar nombre:", p.with_name("ventas_febrero.csv"))
# Out:
# name   → ventas_enero.csv
# stem   → ventas_enero
# suffix → .csv
# parent → data_colab/raw
# parts  → ('data_colab', 'raw', 'ventas_enero.csv')
# Cambiar extensión: data_colab/raw/ventas_enero.txt
# Cambiar nombre: data_colab/raw/ventas_febrero.csv

# %% [markdown]
# ## Crear directorios
# Para crear carpetas (y sus padres) sin errores si ya existen:

# %%
from pathlib import Path

carpeta = Path("data_colab/raw")
carpeta.mkdir(parents=True, exist_ok=True)  # crea data_colab y raw si no existen
print("Existe?", carpeta.exists())          # True
print("¿Es dir?", carpeta.is_dir())         # True
# Out:
# Existe? True
# ¿Es dir? True

# %% [markdown]
# parents=True crea subdirectorios intermedios; exist_ok=True evita falla si ya existían.

# %% [markdown]
# ## Comprobar existencia y tipo
# Antes de operar, puedes verificar:

# %%
p = Path("data_colab/raw/ventas_enero.csv")
print("Existe?", p.exists())
print("¿Es archivo?", p.is_file())
print("¿Es carpeta?", p.is_dir())
# Out:
# Existe? False
# ¿Es archivo? False
# ¿Es carpeta? False

# %% [markdown]
# ## Leer y escribir archivos de texto con Path
#
# Tienes dos estilos: **atajos** (read_text/write_text) o **modo clásico** (open).
#
# Atajos (read_text / write_text)

# %%
from pathlib import Path

p = Path("data_colab/raw/demo.txt")
p.parent.mkdir(parents=True, exist_ok=True)

# SOBRESCRIBE el archivo si ya existe:
p.write_text("Primera línea\nSegunda línea\n", encoding="utf-8")

contenido = p.read_text(encoding="utf-8")
print("Contenido leído:\n", contenido)
# Out:
# Contenido leído:
#  Primera línea
# Segunda línea

# %% [markdown]
# Útiles para casos simples y archivos pequeños. Para archivos grandes o control fino de modos ('a' para append), usa open().
#
# -Estilo clásico con open() (modos, r, w, a)
# "r" → lectura (error si no existe)
#
# "w" → escritura (sobrescribe)
#
# "a" → agregar al final (no borra lo anterior)
#
# Siempre usa encoding="utf-8" para evitar problemas con tildes/ñ.

# %%
p = Path("data_colab/raw/saludo.txt")
# Escribir (w): sobrescribe
with p.open("w", encoding="utf-8") as f:
    f.write("Hola desde pathlib\n")

# Agregar (a): añade al final
with p.open("a", encoding="utf-8") as f:
    f.write("Nueva línea agregada\n")

# Leer (r): iterar por líneas (eficiente)
with p.open("r", encoding="utf-8") as f:
    for linea in f:
        print("→", linea.strip())
# Out:
# → Hola desde pathlib
# → Nueva línea agregada

# %% [markdown]
# ### Archivos grandes. Lectura en chunks

# %%
p = Path("data_colab/raw/grande.txt")
p.write_text("X" * 5000, encoding="utf-8")  # demo simple

with p.open("r", encoding="utf-8") as f:
    bloque = f.read(1024)   # lee 1 KB por iteración
    total = 0
    while bloque:
        total += len(bloque)
        bloque = f.read(1024)
print("Bytes procesados:", total)
# Out:
# Bytes procesados: 5000

# %% [markdown]
# ### Listar y buscar archivos

# %% [markdown]
# -Contenido inmediato de un directorio

# %%
base = Path("data_colab")
for item in base.iterdir():  # no recursivo
    tipo = "dir" if item.is_dir() else "file"
    print(f"{item} → {tipo}")
# Out:
# data_colab/raw → dir

# %% [markdown]
# Buscar por patrón (no recursivo) y recursivo

# %%
base = Path("data_colab")
print("*.txt en data_colab:")
for txt in base.glob("*.txt"):
    print("  -", txt)

print("*.txt en data_colab y subcarpetas:")
for txt in base.rglob("*.txt"):  # recursivo
    print("  -", txt)
# Out:
# *.txt en data_colab:
# *.txt en data_colab y subcarpetas:
#   - data_colab/raw/demo.txt
#   - data_colab/raw/grande.txt
#   - data_colab/raw/saludo.txt

# %% [markdown]
# ### Renombrar, mover, reemplazar y borrar
# rename()y replace() también sirven para mover (si cambias la carpeta destino).

# %%
from pathlib import Path

origen = Path("data_colab/raw/ventas_enero.txt")
origen.write_text("demo\n", encoding="utf-8")

destino = Path("data_colab/procesado/ventas_enero.txt")
destino.parent.mkdir(parents=True, exist_ok=True)

# Mover (o renombrar) archivo:
origen.rename(destino)               # ahora existe en procesado/

# Reemplazar (sobrescribe si destino existe):
nuevo = destino.with_name("ventas_enero_v2.txt")
destino.replace(nuevo)               # move+overwrite

# Borrar de forma segura (no falla si no existe):
nuevo.unlink(missing_ok=True)

# %% [markdown]
# ### Normalizar, expandir y convertir rutas

# %%
from pathlib import Path

print(Path("~/mi_proyecto").expanduser())   # expande ~ a tu HOME

print(Path("data_colab/../data_colab/raw").resolve())  # normaliza la ruta

base = Path("data_colab")
archivo = base / "raw" / "ventas.txt"
print("Relativo a base:", archivo.relative_to(base))  # raw/ventas.txt

p = Path("data_colab/raw/ventas.txt")
print("Formato POSIX:", p.as_posix())  # 'data_colab/raw/ventas.txt'
# print("URI:", p.resolve().as_uri()) # 'file:///content/data_colab/raw/ventas.txt' (requiere ser absoluta)
# Out:
# /root/mi_proyecto
# /content/data_colab/raw
# Relativo a base: raw/ventas.txt
# Formato POSIX: data_colab/raw/ventas.txt

# %% [markdown]
# ### Manejo de errores(aplicado a Colab)
# En operaciones de disco pueden aparecer excepciones típicas:
#
# -FileNotFoundError: la ruta no existe.
#
# -PermissionError: no tienes permisos (poco común en /content, más en rutas del sistema).
#
# -NotADirectoryError: intentas tratar un archivo como carpeta.

# %%
from pathlib import Path

def leer_seguro(ruta: Path) -> str:
    try:
        return ruta.read_text(encoding="utf-8")
    except FileNotFoundError:
        return f"[Error] No existe: {ruta}"
    except PermissionError:
        return f"[Error] Sin permisos: {ruta}"

print(leer_seguro(Path("data_colab/no_existe.txt")))
# Out:
# [Error] No existe: data_colab/no_existe.txt

# %% [markdown]
# ### Persistencia real en Colab con Google Drive (opcional)
# Si quieres conservar tus archivos entre sesiones, monta Drive y trabaja dentro de MyDrive.

# %%
# Ejecuta esto UNA VEZ por sesión (te pedirá autorización)
from google.colab import drive
drive.mount('/content/drive')

# %%
from pathlib import Path

base_drive = Path("/content/drive/MyDrive/mini_bootcamp_python")
(base_drive / "data" / "raw").mkdir(parents=True, exist_ok=True)

archivo = base_drive / "data" / "raw" / "notas.txt"
archivo.write_text("Nota persistente en Drive\n", encoding="utf-8")

print("Guardado en:", archivo)
print("Existe después de reiniciar? Sí, porque está en Drive.")
# Out:
# Guardado en: /content/drive/MyDrive/mini_bootcamp_python/data/raw/notas.txt
# Existe después de reiniciar? Sí, porque está en Drive.

# %% [markdown]
# ## Ejemplo integrador (Colab end-to-end)

# %%
from pathlib import Path

root = Path("inventario_app_colab")        # carpeta del proyecto dentro de /content
carp_data = root / "data"
carp_logs = root / "logs"
carp_reports = root / "reports"

# 1) Crear estructura
for d in (carp_data, carp_logs, carp_reports):
    d.mkdir(parents=True, exist_ok=True)

# 2) Escribir log (append)
log = carp_logs / "app.log"
with log.open("a", encoding="utf-8") as f:
    f.write("Inicio de la aplicación\n")

# 3) Guardar un dataset simple y leerlo
datos = carp_data / "productos.txt"
datos.write_text("SKU-001,Teclado,500.0,3\nSKU-002,Mouse,300.0,5\n", encoding="utf-8")
print("Contenido de productos:\n", datos.read_text(encoding="utf-8"))

# 4) Buscar todos los .txt recursivamente
print("Archivos .txt en el proyecto:")
for txt in root.rglob("*.txt"):
    print("  -", txt)
# Out:
# Contenido de productos:
#  SKU-001,Teclado,500.0,3
# SKU-002,Mouse,300.0,5
#
# Archivos .txt en el proyecto:
#   - inventario_app_colab/data/productos.txt
